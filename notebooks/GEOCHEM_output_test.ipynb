# %% [markdown]
# # Exploring output from an atmospheric chemistry model (GeosCHEM)

# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-272b54e85643> in <module>
#       1 import netCDF4 as nc
#       2 import matplotlib.pyplot as plt
# ----> 3 import xarray as xr
#
# ModuleNotFoundError: No module named 'xarray'

# %%
ds = xr.open_dataset('../data/GEOSChem.SpeciesConc.20160701_0000z.nc4')

# %%
plt.figure(figsize=(12,6),dpi=200.)
ds['SpeciesConc_CO2'].sel(time=ds['time'][0],lev=ds['lev'][10]).plot()

# %%
var.shape
